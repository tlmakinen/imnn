# %% [markdown]
# <a href="https://colab.research.google.com/github/tlmakinen/imnn/blob/0.2a5/IMNN_shell.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd ./examples/
# Out:
# /mnt/home/tmakinen/repositories/imnn/examples

# %%
import tensorflow as tf 

if tf.test.gpu_device_name(): 

    print('Default GPU Device:{}'.format(tf.test.gpu_device_name()))

else:

    print("Please install GPU version of TF")
# Out:
# Default GPU Device:/device:GPU:0

# %%
import numpy as np
import tensorflow as tf
from tensorflow.python.client import device_lib
from IMNN import IMNN
from IMNN.LFI import LFI
from make_data import GenerateGaussianNoise
from make_data import AnalyticLikelihood
import matplotlib.pyplot as plt
import tensorflow_probability as tfp

tfd = tfp.distributions



# for autograd functions
#import jax.numpy as jnp
#from jax import grad, jit, vmap
#from jax import random
#import jax.scipy.special as jspecial

#import numpyro
#import numpyro
#import numpyro.distributions as dist

#key = random.PRNGKey(0)


print("IMNN {}\nTensorFlow {}\nTensorFlow Probability {}\nnumpy {}".format(
    IMNN.__version__, tf.__version__, tfp.__version__, np.__version__))
# Out:
# IMNN 0.2a5
# TensorFlow 2.3.1
# TensorFlow Probability 0.12.0-dev20201017
# numpy 1.18.1

# %%
def get_available_gpus():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type  == "GPU"]

# %%
print(tf.__version__)
# Out:
# 2.3.1

# %% [markdown]
# # IMNN toy model
# Let's try to find a toy problem in which methods like the linear MOPED method fails to recover accurate fiducial parameters, and the IMNN (perhaps) succeeds. We're going to start with generating data on an $N$-dimensional spherical shell. The goal of the exercise will be, given sampled data $\{(x_1, x_2, \dots x_N) \}_i$, with $i = 1, \dots n_d$, we want to recover the fiducial angle in spherical coordinates $\phi$, e.g. $\vec{\theta}_{\rm fid} = (r, \theta, \phi)_{\rm fid}$. Let's get started by coming up with a simulator for the situation.

# %%
# θ_fid ~ {r, θ, \phi, \sigma_θ} = {1., \pi, 2\pi, 0.1}
import argparse
import sys
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IMNN.utils import TFRecords
from IMNN.LFI.LFI import GaussianApproximation

__version__ = "0.2a5"
__author__ = "Lucas Makinen"

class GenerateSpiralData():
    def __init__(self, input_shape=(60,), n_params=2, n_summaries=2, n_s=1000, n_d=1000, n_d_small=100,
                 θ_fid=np.array([1., 0.1]), δθ=np.array([0.1, 0.01]), training_seed=0,
                 validation_seed=1):
        self.input_shape = input_shape
        self.coord_input_shape = (input_shape[0]//3,)
        self.n_params = n_params
        self.n_summaries = n_summaries
        self.n_s = n_s
        self.n_d = n_d
        self.n_d_small = n_d_small
        self.θ_fid = θ_fid
        self.δθ = δθ
        self.half_δθ = δθ / 2.
        self.training_seed = training_seed
        self.validation_seed = validation_seed

    def get_fiducial(self, seed, data):
        return data[seed]

    def get_derivative(self, seed, derivative, parameter, data):
        return data[seed, derivative, parameter]

    def check_selection(self, size):
        if size not in ["full", "all", "small"]:
            print("size must be `full`, `all` or `small` describing, respectively "
                  "whether just `n_d=n_s` is returned, or `n_d=n_s` and `n_d_small` "
                  "is returned, or `n_d=n_d_small` is returned.")
            sys.exit()
    
    def check_ftype(self, ftype):
        if ftype not in ["both", "numpy", "tfrecords"]:
            print("size must be `both`, `numpy` or `tfrecords` describing, respectively "
                  "whether both `numpy` and `tfrecords` files are saved, or just either one.")
            sys.exit()

    def angToCart(self, r, theta, phi):
        return np.array([r*np.cos(theta)*np.sin(phi), 
                         r*np.sin(theta)*np.sin(phi), 
                         r*np.cos(phi)])

    def simulator(self, parameters, seed=None, simulator_args=None):
        # if self.input_shape[0] // 3 != 0:
        #     raise AssertionError ("input shape must be divisible by coordinate dimensions !")
        if seed is not None:
            np.random.seed(seed)
        if len(parameters.shape) == 1:
            parameters = parameters[np.newaxis, :]
        #if self.n_params == 1:
        #    parameters = np.repeat(parameters, 2, axis=1)
        #F    parameters[:, 0] = np.zeros_like(parameters[:, 0])
            
        # phi coordinate is sampled from U(0,2pi)
        phi = np.random.uniform(low=0., high=8*np.pi, size=self.coord_input_shape 
                                + (parameters.shape[0],))
            
        # r coordinate grows linearly according to para[0]*phi
        r = np.random.normal(parameters[:, 0]*phi, np.sqrt(parameters[:,1]), 
                                size=self.coord_input_shape + (parameters.shape[0],))

        # theta is fixed to a cross-section at pi/2
        theta = np.ones((parameters.shape[0],))*np.pi

        
        d = np.zeros((self.input_shape[0],) + (parameters.shape[0],))
        x,y,z = r,theta,phi #self.angToCart(r, theta, phi)
        d[0::3, :] = x
        d[1::3, :] = y
        d[2::3, :] = z

        return np.moveaxis(d,
                  -1, 0)

    def generate_data(self, size="full"):
        self.check_selection(size)
        details = dict(
          input_shape=self.input_shape,
          n_params=self.n_params,
          n_summaries=self.n_summaries,
          n_s=self.n_s,
          n_d=self.n_d,
          θ_fid=self.θ_fid,
          δθ=self.δθ)

        # training base sims
        a_0 = self.simulator(
          parameters=np.repeat(
              self.θ_fid[np.newaxis, :], 
              self.n_s, 
              axis=0),
          seed=self.training_seed,
          simulator_args={"input_shape": self.input_shape})
        # validation base sims
        a_1 = self.simulator(
          parameters=np.repeat(
              self.θ_fid[np.newaxis, :], 
              self.n_s, 
              axis=0),
          seed=self.validation_seed,
          simulator_args={"input_shape": self.input_shape})

        # FOR NOW: ONE parameter: ONLY vary spiral amplitude
        # training -theta
        b_0 = self.simulator(
          parameters=np.repeat(
              np.array([
                  self.θ_fid[0] - self.half_δθ[0],
                  self.θ_fid[1],
                  ])[np.newaxis, :], 
              self.n_d, 
              axis=0),
          seed=self.training_seed,
          simulator_args={"input_shape": self.input_shape})
        # validation -theta
        b_1 = self.simulator(
          parameters=np.repeat(
              np.array([
                  self.θ_fid[0] - self.half_δθ[0],
                  self.θ_fid[1],
                  ])[np.newaxis, :], 
              self.n_d, 
              axis=0),
          seed=self.validation_seed,
          simulator_args={"input_shape": self.input_shape})    
        # training +theta  
        c_0 = self.simulator(
          parameters=np.repeat(
              np.array([
                  self.θ_fid[0] + self.half_δθ[0],
                  self.θ_fid[1],
                  ])[np.newaxis, :], 
              self.n_d, 
              axis=0),
          seed=self.training_seed,
          simulator_args={"input_shape": self.input_shape})
        # validation +theta
        c_1 = self.simulator(
          parameters=np.repeat(
              np.array([
                  self.θ_fid[0] + self.half_δθ[0],
                  self.θ_fid[1],
                  ])[np.newaxis, :], 
              self.n_d, 
              axis=0),
          seed=self.validation_seed,
          simulator_args={"input_shape": self.input_shape})
        # training -sigma2theta
        d_0 = self.simulator(
          parameters=np.repeat(
              np.array([
                  self.θ_fid[0], 
                  self.θ_fid[1] - self.half_δθ[1],
                  ])[np.newaxis, :], 
              self.n_d, 
              axis=0),
          seed=self.training_seed,
          simulator_args={"input_shape": self.input_shape})
        # validation -sigma2theta
        d_1 = self.simulator(
          parameters=np.repeat(
              np.array([
                  self.θ_fid[0], 
                  self.θ_fid[1] - self.half_δθ[1],
                  ])[np.newaxis, :], 
              self.n_d, 
              axis=0),
          seed=self.validation_seed,
          simulator_args={"input_shape": self.input_shape})  
        # training +sigma2theta     
        e_0 = self.simulator(
          parameters=np.repeat(
              np.array([
                  self.θ_fid[0], 
                  self.θ_fid[1] + self.half_δθ[1],
                  ])[np.newaxis, :], 
              self.n_d, 
              axis=0),
          seed=self.training_seed,
          simulator_args={"input_shape": self.input_shape})
        # validation +sigma2theta
        e_1 = self.simulator(
          parameters=np.repeat(
              np.array([
                  self.θ_fid[0], 
                  self.θ_fid[1] + self.half_δθ[1],
                  ])[np.newaxis, :], 
              self.n_d, 
              axis=0),
          seed=self.validation_seed,
          simulator_args={"input_shape": self.input_shape}) 

        #print('b0 shape : ', b_0.shape)
            
        f_0 = np.stack((np.stack((b_0, c_0)),
                          np.stack((d_0, e_0)))
                        ).transpose(2, 0, 1, 3)
        f_1 = np.stack((np.stack((b_1, c_1)),
                          np.stack((d_1, e_1))
                        )).transpose(2, 0, 1, 3)

        result = (details, a_0, a_1, f_0, f_1)
          
        if size == "all":
            details["n_d_small"] = self.n_d_small
            result += (f_0[:self.n_d_small],
                    f_1[:self.n_d_small])
        elif size == "small":
            details["n_d"] = self.n_d_small
            result[-2] = f_0[:self.n_d_small]
            result[-1] = f_1[:self.n_d_small]

        return result
    
    def save(self, ftype="both", size="full", directory="data", record_size=0.01):
        self.check_ftype(ftype)
        result = self.generate_data(size=size)
        
        if (ftype=="both") or (ftype=="numpy"):
            np.savez("{}/details.npz".format(directory), result[0])
            np.save("{}/fiducial.npy".format(directory), result[1])
            np.save("{}/validation_fiducial.npy".format(directory), result[2])    
            np.save("{}/derivative.npy".format(directory), result[3])
            np.save("{}/validation_derivative.npy".format(directory), result[4])
            if size == "all":
                np.save("{}/derivative_small.npy".format(directory), result[5])
                np.save("{}/validation_derivative_small.npy".format(directory), result[6])

        if (ftype=="both") or (ftype=="tfrecords"):
            writer = TFRecords.TFRecords(record_size=record_size)
            
            writer.write_record(
                n_sims=result[0]["n_s"], 
                get_simulation=lambda x : self.get_fiducial(x, result[1]),
                fiducial=True, 
                directory="{}/tfrecords".format(directory))
            writer.write_record(
                n_sims=result[0]["n_s"], 
                get_simulation=lambda x : self.get_fiducial(x, result[2]),
                fiducial=True, 
                validation=True,
                directory="{}/tfrecords".format(directory))
            writer.write_record(
                n_sims=result[0]["n_d"], 
                get_simulation=lambda x, y, z : self.get_derivative(x, y, z, result[3]),
                fiducial=False,
                n_params=result[0]["n_params"],
                directory="{}/tfrecords".format(directory))
            writer.write_record(
                n_sims=result[0]["n_d"], 
                get_simulation=lambda x, y, z : self.get_derivative(x, y, z, result[4]),
                fiducial=False,
                n_params=result[0]["n_params"],
                validation=True,
                directory="{}/tfrecords".format(directory))
            if size == "all":
                writer.write_record(
                    n_sims=result[0]["n_d_small"], 
                    get_simulation=lambda x, y, z : self.get_derivative(x, y, z, result[5]),
                    fiducial=False,
                    n_params=result[0]["n_params"],
                    directory="{}/tfrecords".format(directory),
                    filename="derivative_small")
                writer.write_record(
                    n_sims=result[0]["n_d_small"], 
                    get_simulation=lambda x, y, z : self.get_derivative(x, y, z, result[6]),
                    fiducial=False,
                    n_params=result[0]["n_params"],
                    directory="{}/tfrecords".format(directory),
                    filename="derivative_small")
                
    def plot_data(self, data, ax=None, label=None, 
                  viewang1=20, viewang2=60):

        fig = plt.figure(figsize = (5, 4))
        ax = fig.add_subplot(111, projection='3d')
        print(data.T.shape)
        xs,ys,zs = self.angToCart(data.T[::3], data.T[1::3], data.T[2::3])
        ax.scatter(xs, ys, zs, zdir='z', s=20, c=None, depthshade=True)
        
        ax.legend(frameon=False)
        # ax.set_xticks([])
        # ax.set_zticks([])
        ax.set_xlabel("x");
        ax.set_ylabel("y");
        ax.set_zlabel("z");


        # rotate the axes
        ax.view_init(viewang1, viewang2)
        #ax.set_zlim(-1, 1)
        #ax.set_ylim(-1, 1)
        #ax.set_xlim(-1, 1)

        return fig,ax # for further modification

# %% [markdown]
# Let's take a look at a single simulation of our data:

# %%
generator = GenerateSpiralData(input_shape=(600,))

θ_target = np.array([2.0, 1.0])[np.newaxis, :]
target_data = generator.simulator(
    parameters=θ_target,
    seed=37,
    simulator_args={"input_shape": generator.input_shape})

generator.plot_data(target_data, label="Observed data")
# Out:
# No handles with labels found to put in legend.
# (600, 1)
# (<Figure size 360x288 with 1 Axes>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x1553b30c8d10>)

# %% [markdown]
# Now that we've constructed our simulator, let's generate a set of data with noisy $\varphi$ parameter, draw $\phi$ uniformly at random, and fix $r$. This dataset will correspond to a ring of fixed radius on a 3D sphere. We'll visualize it below.

# %%
# define fiducial parameters and create data vector, d
θ_fid = np.array([1.0, 0.01]) # theta, sigma^2_theta

# %%
SN = GenerateSpiralData(n_s=10000, n_d=10000, input_shape=(300,), n_params=2, θ_fid=θ_fid)
details, fiducial, validation_fiducial, derivative, validation_derivative = SN.generate_data()

# %%
print("fiducial = {}\nvalidation_fiducial = {}\nderivative = {}\nvalidation_derivative = {}".format(
    fiducial.shape, validation_fiducial.shape, derivative.shape, validation_derivative.shape))
# Out:
# fiducial = (10000, 300)
# validation_fiducial = (10000, 300)
# derivative = (10000, 2, 2, 300)
# validation_derivative = (10000, 2, 2, 300)

# %% [markdown]
# Now le but: We want to know firstly how well IMNN can tackle this problem, given a fiducial model to train on. Goals for right now:
#
#
# 1.   Train IMNN on fiducial parameters (set $\alpha_{\rm fid} = 1.0$ for now)
# 2.   Compare to MOPED algorithm

# %%
def fiducial_loader(seed, data):
    yield data[seed], seed

def derivative_loader(seed, derivative, parameter, data):
    yield data[seed, derivative, parameter], (seed, derivative, parameter)

# %%
model = tf.keras.Sequential(
    [tf.keras.Input(shape=SN.input_shape),
     tf.keras.layers.Dense(128),
     tf.keras.layers.LeakyReLU(0.01),
     tf.keras.layers.Dense(128),
     tf.keras.layers.LeakyReLU(0.01),
     tf.keras.layers.Dense(128),
     tf.keras.layers.LeakyReLU(0.01),
     tf.keras.layers.Dense(SN.n_summaries)
     #tf.keras.layers.Conv1D(1,2),
     #tf.keras.layers.Reshape((2,))
    ])
opt = tf.keras.optimizers.Adam()

# %%
θ_fid
# Out:
# array([1.  , 0.01])

# %%
imnn = IMNN.IMNN(n_s=SN.n_s, n_d=SN.n_d, n_params=SN.n_params, n_summaries=SN.n_summaries,
                 model=model, optimiser=opt, θ_fid=np.array([1.0, 1.0]), δθ=np.array([0.01, 0.1]), input_shape=SN.input_shape,
                 fiducial=lambda x : fiducial_loader(x, fiducial), 
                 derivative=lambda x, y, z : derivative_loader(x, y, z, derivative), 
                 validation_fiducial=lambda x : fiducial_loader(x, validation_fiducial),
                 validation_derivative=lambda x, y, z : derivative_loader(x, y, z, validation_derivative), 
                 at_once=SN.n_s, check_shape=True, verbose=True,
                 directory="model", filename="spiral", save=True)
# Out:
# input shape will be (300,)
# saving model to model/spiral
# INFO:tensorflow:Assets written to: model/spiral/assets

# %%
imnn.fit(patience=10, min_iterations=1000, tqdm_notebook=False, checkpoint=100, weight_file='spiral_weights')
# Out:
# Iterations: 0it [00:00, ?it/s]
# Using patience length of 10. Maximum number of training iterations is 10000000000.
# Saving current model in model/spiral
# WARNING:tensorflow:5 out of the last 11 calls to <function IMNN.scatter at 0x1553b2ff49e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function IMNN.scatter at 0x1553b2ff49e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Iterations: 0it [00:46, ?it/s, det_F=0.00578, det_C=74.1, det_Cinv=0.0135, r=10, val_det_F=0.00103, val_det_C=13.9, val_det_Cinv=0.072, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1it [00:46, 46.04s/it, det_F=0.00578, det_C=74.1, det_Cinv=0.0135, r=10, val_det_F=0.00103, val_det_C=13.9, val_det_Cinv=0.072, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1it [00:46, 46.04s/it, det_F=0.000304, det_C=13.9, det_Cinv=0.0721, r=10, val_det_F=0.0646, val_det_C=5.43, val_det_Cinv=0.184, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 2it [00:46, 32.40s/it, det_F=0.000304, det_C=13.9, det_Cinv=0.0721, r=10, val_det_F=0.0646, val_det_C=5.43, val_det_Cinv=0.184, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 2it [00:47, 32.40s/it, det_F=0.0972, det_C=5.5, det_Cinv=0.182, r=10, val_det_F=0.234, val_det_C=3.49, val_det_Cinv=0.287, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 3it [00:47, 22.83s/it, det_F=0.0972, det_C=5.5, det_Cinv=0.182, r=10, val_det_F=0.234, val_det_C=3.49, val_det_Cinv=0.287, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 3it [00:47, 22.83s/it, det_F=0.262, det_C=3.64, det_Cinv=0.275, r=10, val_det_F=0.371, val_det_C=2.89, val_det_Cinv=0.346, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 4it [00:47, 16.13s/it, det_F=0.262, det_C=3.64, det_Cinv=0.275, r=10, val_det_F=0.371, val_det_C=2.89, val_det_Cinv=0.346, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 4it [00:48, 16.13s/it, det_F=0.359, det_C=3.06, det_Cinv=0.327, r=10, val_det_F=0.481, val_det_C=2.58, val_det_Cinv=0.387, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 5it [00:48, 11.44s/it, det_F=0.359, det_C=3.06, det_Cinv=0.327, r=10, val_det_F=0.481, val_det_C=2.58, val_det_Cinv=0.387, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 5it [00:48, 11.44s/it, det_F=0.414, det_C=2.74, det_Cinv=0.365, r=10, val_det_F=0.484, val_det_C=2.28, val_det_Cinv=0.439, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 6it [00:48,  8.16s/it, det_F=0.414, det_C=2.74, det_Cinv=0.365, r=10, val_det_F=0.484, val_det_C=2.28, val_det_Cinv=0.439, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 6it [00:49,  8.16s/it, det_F=0.526, det_C=2.41, det_Cinv=0.414, r=10, val_det_F=0.548, val_det_C=1.95, val_det_Cinv=0.512, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 7it [00:49,  5.86s/it, det_F=0.526, det_C=2.41, det_Cinv=0.414, r=10, val_det_F=0.548, val_det_C=1.95, val_det_Cinv=0.512, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 7it [00:49,  5.86s/it, det_F=0.623, det_C=2.07, det_Cinv=0.484, r=10, val_det_F=0.666, val_det_C=1.64, val_det_Cinv=0.608, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 8it [00:49,  4.25s/it, det_F=0.623, det_C=2.07, det_Cinv=0.484, r=10, val_det_F=0.666, val_det_C=1.64, val_det_Cinv=0.608, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 8it [00:50,  4.25s/it, det_F=0.674, det_C=1.72, det_Cinv=0.58, r=10, val_det_F=0.714, val_det_C=1.39, val_det_Cinv=0.721, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 9it [00:50,  3.12s/it, det_F=0.674, det_C=1.72, det_Cinv=0.58, r=10, val_det_F=0.714, val_det_C=1.39, val_det_Cinv=0.721, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 9it [00:50,  3.12s/it, det_F=0.694, det_C=1.43, det_Cinv=0.698, r=10, val_det_F=0.756, val_det_C=1.18, val_det_Cinv=0.845, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 10it [00:50,  2.33s/it, det_F=0.694, det_C=1.43, det_Cinv=0.698, r=10, val_det_F=0.756, val_det_C=1.18, val_det_Cinv=0.845, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 10it [00:51,  2.33s/it, det_F=0.758, det_C=1.21, det_Cinv=0.827, r=10, val_det_F=0.83, val_det_C=1.04, val_det_Cinv=0.965, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 11it [00:51,  1.78s/it, det_F=0.758, det_C=1.21, det_Cinv=0.827, r=10, val_det_F=0.83, val_det_C=1.04, val_det_Cinv=0.965, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 11it [00:51,  1.78s/it, det_F=0.798, det_C=1.05, det_Cinv=0.953, r=9.91, val_det_F=0.903, val_det_C=0.933, val_det_Cinv=1.07, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 12it [00:51,  1.40s/it, det_F=0.798, det_C=1.05, det_Cinv=0.953, r=9.91, val_det_F=0.903, val_det_C=0.933, val_det_Cinv=1.07, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 12it [00:52,  1.40s/it, det_F=0.848, det_C=0.94, det_Cinv=1.06, r=9.15, val_det_F=0.973, val_det_C=0.874, val_det_Cinv=1.14, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 13it [00:52,  1.13s/it, det_F=0.848, det_C=0.94, det_Cinv=1.06, r=9.15, val_det_F=0.973, val_det_C=0.874, val_det_Cinv=1.14, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 13it [00:52,  1.13s/it, det_F=1.03, det_C=0.876, det_Cinv=1.14, r=6.66, val_det_F=1.15, val_det_C=0.858, val_det_Cinv=1.17, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 14it [00:52,  1.07it/s, det_F=1.03, det_C=0.876, det_Cinv=1.14, r=6.66, val_det_F=1.15, val_det_C=0.858, val_det_Cinv=1.17, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 14it [00:53,  1.07it/s, det_F=1.05, det_C=0.857, det_Cinv=1.17, r=2.79, val_det_F=1.31, val_det_C=0.868, val_det_Cinv=1.15, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 15it [00:53,  1.25it/s, det_F=1.05, det_C=0.857, det_Cinv=1.17, r=2.79, val_det_F=1.31, val_det_C=0.868, val_det_Cinv=1.15, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 15it [00:53,  1.25it/s, det_F=1.22, det_C=0.864, det_Cinv=1.16, r=4.26, val_det_F=1.39, val_det_C=0.903, val_det_Cinv=1.11, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 16it [00:53,  1.41it/s, det_F=1.22, det_C=0.864, det_Cinv=1.16, r=4.26, val_det_F=1.39, val_det_C=0.903, val_det_Cinv=1.11, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 16it [00:54,  1.41it/s, det_F=1.38, det_C=0.897, det_Cinv=1.12, r=8.73, val_det_F=1.65, val_det_C=0.947, val_det_Cinv=1.06, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 17it [00:54,  1.54it/s, det_F=1.38, det_C=0.897, det_Cinv=1.12, r=8.73, val_det_F=1.65, val_det_C=0.947, val_det_Cinv=1.06, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 17it [00:54,  1.54it/s, det_F=1.57, det_C=0.938, det_Cinv=1.07, r=9.77, val_det_F=1.89, val_det_C=0.991, val_det_Cinv=1.01, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 18it [00:54,  1.66it/s, det_F=1.57, det_C=0.938, det_Cinv=1.07, r=9.77, val_det_F=1.89, val_det_C=0.991, val_det_Cinv=1.01, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 18it [00:55,  1.66it/s, det_F=1.93, det_C=0.979, det_Cinv=1.02, r=9.78, val_det_F=2.37, val_det_C=1.03, val_det_Cinv=0.973, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 19it [00:55,  1.75it/s, det_F=1.93, det_C=0.979, det_Cinv=1.02, r=9.78, val_det_F=2.37, val_det_C=1.03, val_det_Cinv=0.973, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 19it [00:55,  1.75it/s, det_F=2.33, det_C=1.01, det_Cinv=0.989, r=8.69, val_det_F=2.82, val_det_C=1.05, val_det_Cinv=0.95, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 20it [00:55,  1.82it/s, det_F=2.33, det_C=1.01, det_Cinv=0.989, r=8.69, val_det_F=2.82, val_det_C=1.05, val_det_Cinv=0.95, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 20it [00:56,  1.82it/s, det_F=2.76, det_C=1.03, det_Cinv=0.968, r=1.34, val_det_F=3.21, val_det_C=1.07, val_det_Cinv=0.931, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 21it [00:56,  1.87it/s, det_F=2.76, det_C=1.03, det_Cinv=0.968, r=1.34, val_det_F=3.21, val_det_C=1.07, val_det_Cinv=0.931, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 21it [00:56,  1.87it/s, det_F=3.29, det_C=1.05, det_Cinv=0.951, r=0.106, val_det_F=3.88, val_det_C=1.09, val_det_Cinv=0.914, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 22it [00:56,  1.91it/s, det_F=3.29, det_C=1.05, det_Cinv=0.951, r=0.106, val_det_F=3.88, val_det_C=1.09, val_det_Cinv=0.914, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 22it [00:57,  1.91it/s, det_F=3.93, det_C=1.07, det_Cinv=0.936, r=0.0594, val_det_F=4.71, val_det_C=1.11, val_det_Cinv=0.901, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 23it [00:57,  1.94it/s, det_F=3.93, det_C=1.07, det_Cinv=0.936, r=0.0594, val_det_F=4.71, val_det_C=1.11, val_det_Cinv=0.901, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 23it [00:57,  1.94it/s, det_F=4.83, det_C=1.08, det_Cinv=0.924, r=0.241, val_det_F=5.72, val_det_C=1.13, val_det_Cinv=0.888, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 24it [00:57,  1.95it/s, det_F=4.83, det_C=1.08, det_Cinv=0.924, r=0.241, val_det_F=5.72, val_det_C=1.13, val_det_Cinv=0.888, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 24it [00:58,  1.95it/s, det_F=5.97, det_C=1.1, det_Cinv=0.913, r=1.61, val_det_F=6.79, val_det_C=1.13, val_det_Cinv=0.884, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 25it [00:58,  1.97it/s, det_F=5.97, det_C=1.1, det_Cinv=0.913, r=1.61, val_det_F=6.79, val_det_C=1.13, val_det_Cinv=0.884, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 25it [00:58,  1.97it/s, det_F=7.32, det_C=1.1, det_Cinv=0.91, r=5.09, val_det_F=8.18, val_det_C=1.12, val_det_Cinv=0.895, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 26it [00:58,  1.99it/s, det_F=7.32, det_C=1.1, det_Cinv=0.91, r=5.09, val_det_F=8.18, val_det_C=1.12, val_det_Cinv=0.895, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 26it [00:59,  1.99it/s, det_F=8.77, det_C=1.08, det_Cinv=0.924, r=4.3, val_det_F=9.93, val_det_C=1.09, val_det_Cinv=0.917, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 27it [00:59,  1.99it/s, det_F=8.77, det_C=1.08, det_Cinv=0.924, r=4.3, val_det_F=9.93, val_det_C=1.09, val_det_Cinv=0.917, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 27it [00:59,  1.99it/s, det_F=10.3, det_C=1.05, det_Cinv=0.948, r=1.12, val_det_F=12.1, val_det_C=1.07, val_det_Cinv=0.939, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 28it [00:59,  2.00it/s, det_F=10.3, det_C=1.05, det_Cinv=0.948, r=1.12, val_det_F=12.1, val_det_C=1.07, val_det_Cinv=0.939, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 28it [01:00,  2.00it/s, det_F=12, det_C=1.03, det_Cinv=0.973, r=0.23, val_det_F=14.4, val_det_C=1.04, val_det_Cinv=0.96, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 29it [01:00,  2.01it/s, det_F=12, det_C=1.03, det_Cinv=0.973, r=0.23, val_det_F=14.4, val_det_C=1.04, val_det_Cinv=0.96, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 29it [01:00,  2.01it/s, det_F=14, det_C=1, det_Cinv=0.997, r=0.0729, val_det_F=17.3, val_det_C=1.02, val_det_Cinv=0.981, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 30it [01:00,  2.01it/s, det_F=14, det_C=1, det_Cinv=0.997, r=0.0729, val_det_F=17.3, val_det_C=1.02, val_det_Cinv=0.981, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 30it [01:01,  2.01it/s, det_F=16.6, det_C=0.98, det_Cinv=1.02, r=0.0614, val_det_F=20.6, val_det_C=0.997, val_det_Cinv=1, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 31it [01:01,  2.01it/s, det_F=16.6, det_C=0.98, det_Cinv=1.02, r=0.0614, val_det_F=20.6, val_det_C=0.997, val_det_Cinv=1, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 31it [01:01,  2.01it/s, det_F=19.8, det_C=0.959, det_Cinv=1.04, r=0.127, val_det_F=23.6, val_det_C=0.976, val_det_Cinv=1.02, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 32it [01:01,  2.00it/s, det_F=19.8, det_C=0.959, det_Cinv=1.04, r=0.127, val_det_F=23.6, val_det_C=0.976, val_det_Cinv=1.02, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 32it [01:02,  2.00it/s, det_F=22.9, det_C=0.937, det_Cinv=1.07, r=0.398, val_det_F=26.7, val_det_C=0.956, val_det_Cinv=1.05, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 33it [01:02,  2.01it/s, det_F=22.9, det_C=0.937, det_Cinv=1.07, r=0.398, val_det_F=26.7, val_det_C=0.956, val_det_Cinv=1.05, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 33it [01:02,  2.01it/s, det_F=26.4, det_C=0.918, det_Cinv=1.09, r=1.41, val_det_F=29.8, val_det_C=0.944, val_det_Cinv=1.06, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 34it [01:02,  2.01it/s, det_F=26.4, det_C=0.918, det_Cinv=1.09, r=1.41, val_det_F=29.8, val_det_C=0.944, val_det_Cinv=1.06, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 34it [01:03,  2.01it/s, det_F=30.7, det_C=0.905, det_Cinv=1.11, r=2.98, val_det_F=33.2, val_det_C=0.949, val_det_Cinv=1.05, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 35it [01:03,  2.01it/s, det_F=30.7, det_C=0.905, det_Cinv=1.11, r=2.98, val_det_F=33.2, val_det_C=0.949, val_det_Cinv=1.05, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 35it [01:03,  2.01it/s, det_F=35.5, det_C=0.91, det_Cinv=1.1, r=1.85, val_det_F=37.9, val_det_C=0.965, val_det_Cinv=1.04, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 36it [01:03,  2.01it/s, det_F=35.5, det_C=0.91, det_Cinv=1.1, r=1.85, val_det_F=37.9, val_det_C=0.965, val_det_Cinv=1.04, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 36it [01:04,  2.01it/s, det_F=40.7, det_C=0.924, det_Cinv=1.08, r=0.544, val_det_F=44.1, val_det_C=0.981, val_det_Cinv=1.02, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 37it [01:04,  2.02it/s, det_F=40.7, det_C=0.924, det_Cinv=1.08, r=0.544, val_det_F=44.1, val_det_C=0.981, val_det_Cinv=1.02, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 37it [01:04,  2.02it/s, det_F=45.8, det_C=0.939, det_Cinv=1.06, r=0.171, val_det_F=50.3, val_det_C=0.994, val_det_Cinv=1.01, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 38it [01:04,  2.02it/s, det_F=45.8, det_C=0.939, det_Cinv=1.06, r=0.171, val_det_F=50.3, val_det_C=0.994, val_det_Cinv=1.01, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 38it [01:05,  2.02it/s, det_F=52.2, det_C=0.951, det_Cinv=1.05, r=0.0668, val_det_F=56.9, val_det_C=1.01, val_det_Cinv=0.995, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 39it [01:05,  2.01it/s, det_F=52.2, det_C=0.951, det_Cinv=1.05, r=0.0668, val_det_F=56.9, val_det_C=1.01, val_det_Cinv=0.995, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 39it [01:05,  2.01it/s, det_F=59.5, det_C=0.962, det_Cinv=1.04, r=0.0346, val_det_F=65.2, val_det_C=1.01, val_det_Cinv=0.986, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 40it [01:05,  2.01it/s, det_F=59.5, det_C=0.962, det_Cinv=1.04, r=0.0346, val_det_F=65.2, val_det_C=1.01, val_det_Cinv=0.986, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 40it [01:05,  2.01it/s, det_F=68, det_C=0.969, det_Cinv=1.03, r=0.0246, val_det_F=74, val_det_C=1.02, val_det_Cinv=0.98, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 41it [01:05,  2.01it/s, det_F=68, det_C=0.969, det_Cinv=1.03, r=0.0246, val_det_F=74, val_det_C=1.02, val_det_Cinv=0.98, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 41it [01:06,  2.01it/s, det_F=77.8, det_C=0.975, det_Cinv=1.03, r=0.0207, val_det_F=82.5, val_det_C=1.02, val_det_Cinv=0.977, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 42it [01:06,  2.01it/s, det_F=77.8, det_C=0.975, det_Cinv=1.03, r=0.0207, val_det_F=82.5, val_det_C=1.02, val_det_Cinv=0.977, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 42it [01:06,  2.01it/s, det_F=89, det_C=0.978, det_Cinv=1.02, r=0.0191, val_det_F=91.7, val_det_C=1.02, val_det_Cinv=0.977, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 43it [01:06,  2.02it/s, det_F=89, det_C=0.978, det_Cinv=1.02, r=0.0191, val_det_F=91.7, val_det_C=1.02, val_det_Cinv=0.977, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 43it [01:07,  2.02it/s, det_F=101, det_C=0.977, det_Cinv=1.02, r=0.0172, val_det_F=103, val_det_C=1.02, val_det_Cinv=0.978, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 44it [01:07,  2.02it/s, det_F=101, det_C=0.977, det_Cinv=1.02, r=0.0172, val_det_F=103, val_det_C=1.02, val_det_Cinv=0.978, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 44it [01:07,  2.02it/s, det_F=116, det_C=0.977, det_Cinv=1.02, r=0.0131, val_det_F=118, val_det_C=1.02, val_det_Cinv=0.976, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 45it [01:07,  2.03it/s, det_F=116, det_C=0.977, det_Cinv=1.02, r=0.0131, val_det_F=118, val_det_C=1.02, val_det_Cinv=0.976, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 45it [01:08,  2.03it/s, det_F=132, det_C=0.978, det_Cinv=1.02, r=0.00759, val_det_F=133, val_det_C=1.03, val_det_Cinv=0.975, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 46it [01:08,  2.02it/s, det_F=132, det_C=0.978, det_Cinv=1.02, r=0.00759, val_det_F=133, val_det_C=1.03, val_det_Cinv=0.975, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 46it [01:08,  2.02it/s, det_F=150, det_C=0.978, det_Cinv=1.02, r=0.00424, val_det_F=152, val_det_C=1.03, val_det_Cinv=0.974, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 47it [01:08,  2.02it/s, det_F=150, det_C=0.978, det_Cinv=1.02, r=0.00424, val_det_F=152, val_det_C=1.03, val_det_Cinv=0.974, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 47it [01:09,  2.02it/s, det_F=169, det_C=0.977, det_Cinv=1.02, r=0.00336, val_det_F=173, val_det_C=1.03, val_det_Cinv=0.972, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 48it [01:09,  2.01it/s, det_F=169, det_C=0.977, det_Cinv=1.02, r=0.00336, val_det_F=173, val_det_C=1.03, val_det_Cinv=0.972, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 48it [01:09,  2.01it/s, det_F=194, det_C=0.977, det_Cinv=1.02, r=0.00542, val_det_F=195, val_det_C=1.03, val_det_Cinv=0.97, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 49it [01:09,  2.01it/s, det_F=194, det_C=0.977, det_Cinv=1.02, r=0.00542, val_det_F=195, val_det_C=1.03, val_det_Cinv=0.97, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 49it [01:10,  2.01it/s, det_F=219, det_C=0.976, det_Cinv=1.02, r=0.0116, val_det_F=220, val_det_C=1.03, val_det_Cinv=0.968, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 50it [01:10,  2.01it/s, det_F=219, det_C=0.976, det_Cinv=1.02, r=0.0116, val_det_F=220, val_det_C=1.03, val_det_Cinv=0.968, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 50it [01:10,  2.01it/s, det_F=247, det_C=0.976, det_Cinv=1.02, r=0.0237, val_det_F=247, val_det_C=1.04, val_det_Cinv=0.966, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 51it [01:10,  2.01it/s, det_F=247, det_C=0.976, det_Cinv=1.02, r=0.0237, val_det_F=247, val_det_C=1.04, val_det_Cinv=0.966, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 51it [01:11,  2.01it/s, det_F=281, det_C=0.975, det_Cinv=1.03, r=0.0463, val_det_F=278, val_det_C=1.04, val_det_Cinv=0.961, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 52it [01:11,  2.01it/s, det_F=281, det_C=0.975, det_Cinv=1.03, r=0.0463, val_det_F=278, val_det_C=1.04, val_det_Cinv=0.961, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 52it [01:11,  2.01it/s, det_F=318, det_C=0.977, det_Cinv=1.02, r=0.0844, val_det_F=309, val_det_C=1.05, val_det_Cinv=0.956, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 53it [01:11,  2.01it/s, det_F=318, det_C=0.977, det_Cinv=1.02, r=0.0844, val_det_F=309, val_det_C=1.05, val_det_Cinv=0.956, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 53it [01:12,  2.01it/s, det_F=357, det_C=0.979, det_Cinv=1.02, r=0.152, val_det_F=346, val_det_C=1.05, val_det_Cinv=0.951, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 54it [01:12,  2.00it/s, det_F=357, det_C=0.979, det_Cinv=1.02, r=0.152, val_det_F=346, val_det_C=1.05, val_det_Cinv=0.951, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 54it [01:12,  2.00it/s, det_F=403, det_C=0.982, det_Cinv=1.02, r=0.283, val_det_F=386, val_det_C=1.05, val_det_Cinv=0.948, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 55it [01:12,  2.00it/s, det_F=403, det_C=0.982, det_Cinv=1.02, r=0.283, val_det_F=386, val_det_C=1.05, val_det_Cinv=0.948, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 55it [01:13,  2.00it/s, det_F=448, det_C=0.984, det_Cinv=1.02, r=0.492, val_det_F=432, val_det_C=1.06, val_det_Cinv=0.946, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 56it [01:13,  2.00it/s, det_F=448, det_C=0.984, det_Cinv=1.02, r=0.492, val_det_F=432, val_det_C=1.06, val_det_Cinv=0.946, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 56it [01:13,  2.00it/s, det_F=501, det_C=0.983, det_Cinv=1.02, r=0.685, val_det_F=478, val_det_C=1.06, val_det_Cinv=0.944, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 57it [01:13,  2.00it/s, det_F=501, det_C=0.983, det_Cinv=1.02, r=0.685, val_det_F=478, val_det_C=1.06, val_det_Cinv=0.944, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 57it [01:14,  2.00it/s, det_F=564, det_C=0.984, det_Cinv=1.02, r=0.695, val_det_F=525, val_det_C=1.06, val_det_Cinv=0.94, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 58it [01:14,  2.01it/s, det_F=564, det_C=0.984, det_Cinv=1.02, r=0.695, val_det_F=525, val_det_C=1.06, val_det_Cinv=0.94, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 58it [01:14,  2.01it/s, det_F=628, det_C=0.987, det_Cinv=1.01, r=0.488, val_det_F=577, val_det_C=1.07, val_det_Cinv=0.936, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 59it [01:14,  2.01it/s, det_F=628, det_C=0.987, det_Cinv=1.01, r=0.488, val_det_F=577, val_det_C=1.07, val_det_Cinv=0.936, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 59it [01:15,  2.01it/s, det_F=695, det_C=0.989, det_Cinv=1.01, r=0.309, val_det_F=637, val_det_C=1.07, val_det_Cinv=0.935, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 60it [01:15,  2.02it/s, det_F=695, det_C=0.989, det_Cinv=1.01, r=0.309, val_det_F=637, val_det_C=1.07, val_det_Cinv=0.935, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 60it [01:15,  2.02it/s, det_F=774, det_C=0.989, det_Cinv=1.01, r=0.229, val_det_F=708, val_det_C=1.07, val_det_Cinv=0.937, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 61it [01:15,  2.02it/s, det_F=774, det_C=0.989, det_Cinv=1.01, r=0.229, val_det_F=708, val_det_C=1.07, val_det_Cinv=0.937, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 61it [01:16,  2.02it/s, det_F=864, det_C=0.987, det_Cinv=1.01, r=0.203, val_det_F=787, val_det_C=1.06, val_det_Cinv=0.94, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 62it [01:16,  2.03it/s, det_F=864, det_C=0.987, det_Cinv=1.01, r=0.203, val_det_F=787, val_det_C=1.06, val_det_Cinv=0.94, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 62it [01:16,  2.03it/s, det_F=961, det_C=0.984, det_Cinv=1.02, r=0.226, val_det_F=874, val_det_C=1.06, val_det_Cinv=0.944, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 63it [01:16,  2.03it/s, det_F=961, det_C=0.984, det_Cinv=1.02, r=0.226, val_det_F=874, val_det_C=1.06, val_det_Cinv=0.944, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 63it [01:17,  2.03it/s, det_F=1.07e+3, det_C=0.979, det_Cinv=1.02, r=0.312, val_det_F=971, val_det_C=1.05, val_det_Cinv=0.949, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 64it [01:17,  2.03it/s, det_F=1.07e+3, det_C=0.979, det_Cinv=1.02, r=0.312, val_det_F=971, val_det_C=1.05, val_det_Cinv=0.949, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 64it [01:17,  2.03it/s, det_F=1.19e+3, det_C=0.973, det_Cinv=1.03, r=0.457, val_det_F=1.08e+3, val_det_C=1.05, val_det_Cinv=0.954, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 65it [01:17,  2.03it/s, det_F=1.19e+3, det_C=0.973, det_Cinv=1.03, r=0.457, val_det_F=1.08e+3, val_det_C=1.05, val_det_Cinv=0.954, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 65it [01:18,  2.03it/s, det_F=1.32e+3, det_C=0.968, det_Cinv=1.03, r=0.585, val_det_F=1.19e+3, val_det_C=1.05, val_det_Cinv=0.956, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 66it [01:18,  2.03it/s, det_F=1.32e+3, det_C=0.968, det_Cinv=1.03, r=0.585, val_det_F=1.19e+3, val_det_C=1.05, val_det_Cinv=0.956, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 66it [01:18,  2.03it/s, det_F=1.46e+3, det_C=0.966, det_Cinv=1.04, r=0.57, val_det_F=1.31e+3, val_det_C=1.04, val_det_Cinv=0.957, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 67it [01:18,  2.03it/s, det_F=1.46e+3, det_C=0.966, det_Cinv=1.04, r=0.57, val_det_F=1.31e+3, val_det_C=1.04, val_det_Cinv=0.957, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 67it [01:19,  2.03it/s, det_F=1.62e+3, det_C=0.964, det_Cinv=1.04, r=0.456, val_det_F=1.45e+3, val_det_C=1.04, val_det_Cinv=0.96, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 68it [01:19,  2.02it/s, det_F=1.62e+3, det_C=0.964, det_Cinv=1.04, r=0.456, val_det_F=1.45e+3, val_det_C=1.04, val_det_Cinv=0.96, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 68it [01:19,  2.02it/s, det_F=1.79e+3, det_C=0.961, det_Cinv=1.04, r=0.353, val_det_F=1.6e+3, val_det_C=1.04, val_det_Cinv=0.963, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 69it [01:19,  2.01it/s, det_F=1.79e+3, det_C=0.961, det_Cinv=1.04, r=0.353, val_det_F=1.6e+3, val_det_C=1.04, val_det_Cinv=0.963, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 69it [01:20,  2.01it/s, det_F=1.97e+3, det_C=0.959, det_Cinv=1.04, r=0.274, val_det_F=1.77e+3, val_det_C=1.04, val_det_Cinv=0.965, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 70it [01:20,  2.01it/s, det_F=1.97e+3, det_C=0.959, det_Cinv=1.04, r=0.274, val_det_F=1.77e+3, val_det_C=1.04, val_det_Cinv=0.965, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 70it [01:20,  2.01it/s, det_F=2.17e+3, det_C=0.956, det_Cinv=1.05, r=0.239, val_det_F=1.95e+3, val_det_C=1.03, val_det_Cinv=0.97, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 71it [01:20,  2.02it/s, det_F=2.17e+3, det_C=0.956, det_Cinv=1.05, r=0.239, val_det_F=1.95e+3, val_det_C=1.03, val_det_Cinv=0.97, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 71it [01:21,  2.02it/s, det_F=2.4e+3, det_C=0.951, det_Cinv=1.05, r=0.265, val_det_F=2.17e+3, val_det_C=1.03, val_det_Cinv=0.973, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 72it [01:21,  2.01it/s, det_F=2.4e+3, det_C=0.951, det_Cinv=1.05, r=0.265, val_det_F=2.17e+3, val_det_C=1.03, val_det_Cinv=0.973, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 72it [01:21,  2.01it/s, det_F=2.66e+3, det_C=0.948, det_Cinv=1.06, r=0.307, val_det_F=2.4e+3, val_det_C=1.03, val_det_Cinv=0.975, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 73it [01:21,  2.01it/s, det_F=2.66e+3, det_C=0.948, det_Cinv=1.06, r=0.307, val_det_F=2.4e+3, val_det_C=1.03, val_det_Cinv=0.975, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 73it [01:22,  2.01it/s, det_F=2.95e+3, det_C=0.946, det_Cinv=1.06, r=0.363, val_det_F=2.67e+3, val_det_C=1.02, val_det_Cinv=0.976, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 74it [01:22,  2.01it/s, det_F=2.95e+3, det_C=0.946, det_Cinv=1.06, r=0.363, val_det_F=2.67e+3, val_det_C=1.02, val_det_Cinv=0.976, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 74it [01:22,  2.01it/s, det_F=3.25e+3, det_C=0.944, det_Cinv=1.06, r=0.436, val_det_F=2.95e+3, val_det_C=1.02, val_det_Cinv=0.979, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 75it [01:22,  2.01it/s, det_F=3.25e+3, det_C=0.944, det_Cinv=1.06, r=0.436, val_det_F=2.95e+3, val_det_C=1.02, val_det_Cinv=0.979, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 75it [01:23,  2.01it/s, det_F=3.6e+3, det_C=0.941, det_Cinv=1.06, r=0.484, val_det_F=3253.17, val_det_C=1.02, val_det_Cinv=0.978, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 76it [01:23,  2.01it/s, det_F=3.6e+3, det_C=0.941, det_Cinv=1.06, r=0.484, val_det_F=3253.17, val_det_C=1.02, val_det_Cinv=0.978, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 76it [01:23,  2.01it/s, det_F=3.97e+3, det_C=0.943, det_Cinv=1.06, r=0.441, val_det_F=3.59e+3, val_det_C=1.03, val_det_Cinv=0.974, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 77it [01:23,  2.00it/s, det_F=3.97e+3, det_C=0.943, det_Cinv=1.06, r=0.441, val_det_F=3.59e+3, val_det_C=1.03, val_det_Cinv=0.974, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 77it [01:24,  2.00it/s, det_F=4.39e+3, det_C=0.947, det_Cinv=1.06, r=0.358, val_det_F=3.98e+3, val_det_C=1.03, val_det_Cinv=0.973, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 78it [01:24,  2.01it/s, det_F=4.39e+3, det_C=0.947, det_Cinv=1.06, r=0.358, val_det_F=3.98e+3, val_det_C=1.03, val_det_Cinv=0.973, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 78it [01:24,  2.01it/s, det_F=4.86e+3, det_C=0.948, det_Cinv=1.06, r=0.324, val_det_F=4.4e+3, val_det_C=1.03, val_det_Cinv=0.974, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 79it [01:24,  2.02it/s, det_F=4.86e+3, det_C=0.948, det_Cinv=1.06, r=0.324, val_det_F=4.4e+3, val_det_C=1.03, val_det_Cinv=0.974, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 79it [01:25,  2.02it/s, det_F=5.39e+3, det_C=0.947, det_Cinv=1.06, r=0.312, val_det_F=4.88e+3, val_det_C=1.02, val_det_Cinv=0.976, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 80it [01:25,  2.01it/s, det_F=5.39e+3, det_C=0.947, det_Cinv=1.06, r=0.312, val_det_F=4.88e+3, val_det_C=1.02, val_det_Cinv=0.976, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 80it [01:25,  2.01it/s, det_F=5.98e+3, det_C=0.946, det_Cinv=1.06, r=0.307, val_det_F=5.43e+3, val_det_C=1.02, val_det_Cinv=0.978, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 81it [01:25,  2.01it/s, det_F=5.98e+3, det_C=0.946, det_Cinv=1.06, r=0.307, val_det_F=5.43e+3, val_det_C=1.02, val_det_Cinv=0.978, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 81it [01:26,  2.01it/s, det_F=6.64e+3, det_C=0.944, det_Cinv=1.06, r=0.306, val_det_F=6.05e+3, val_det_C=1.02, val_det_Cinv=0.979, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 82it [01:26,  2.02it/s, det_F=6.64e+3, det_C=0.944, det_Cinv=1.06, r=0.306, val_det_F=6.05e+3, val_det_C=1.02, val_det_Cinv=0.979, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 82it [01:26,  2.02it/s, det_F=7.38e+3, det_C=0.943, det_Cinv=1.06, r=0.303, val_det_F=6.76e+3, val_det_C=1.02, val_det_Cinv=0.981, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 83it [01:26,  2.02it/s, det_F=7.38e+3, det_C=0.943, det_Cinv=1.06, r=0.303, val_det_F=6.76e+3, val_det_C=1.02, val_det_Cinv=0.981, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 83it [01:27,  2.02it/s, det_F=8.22e+3, det_C=0.942, det_Cinv=1.06, r=0.301, val_det_F=7.55e+3, val_det_C=1.01, val_det_Cinv=0.987, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 84it [01:27,  2.02it/s, det_F=8.22e+3, det_C=0.942, det_Cinv=1.06, r=0.301, val_det_F=7.55e+3, val_det_C=1.01, val_det_Cinv=0.987, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 84it [01:27,  2.02it/s, det_F=9.17e+3, det_C=0.937, det_Cinv=1.07, r=0.333, val_det_F=8.44e+3, val_det_C=1.01, val_det_Cinv=0.993, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 85it [01:27,  2.02it/s, det_F=9.17e+3, det_C=0.937, det_Cinv=1.07, r=0.333, val_det_F=8.44e+3, val_det_C=1.01, val_det_Cinv=0.993, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 85it [01:28,  2.02it/s, det_F=1.02e+4, det_C=0.931, det_Cinv=1.07, r=0.393, val_det_F=9.45e+3, val_det_C=1, val_det_Cinv=0.998, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 86it [01:28,  2.01it/s, det_F=1.02e+4, det_C=0.931, det_Cinv=1.07, r=0.393, val_det_F=9.45e+3, val_det_C=1, val_det_Cinv=0.998, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 86it [01:28,  2.01it/s, det_F=1.14e+4, det_C=0.928, det_Cinv=1.08, r=0.405, val_det_F=1.06e+4, val_det_C=1, val_det_Cinv=0.998, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 87it [01:28,  2.01it/s, det_F=1.14e+4, det_C=0.928, det_Cinv=1.08, r=0.405, val_det_F=1.06e+4, val_det_C=1, val_det_Cinv=0.998, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 87it [01:29,  2.01it/s, det_F=1.28e+4, det_C=0.928, det_Cinv=1.08, r=0.343, val_det_F=1.19e+4, val_det_C=1, val_det_Cinv=0.996, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 88it [01:29,  2.01it/s, det_F=1.28e+4, det_C=0.928, det_Cinv=1.08, r=0.343, val_det_F=1.19e+4, val_det_C=1, val_det_Cinv=0.996, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 88it [01:29,  2.01it/s, det_F=1.43e+4, det_C=0.93, det_Cinv=1.07, r=0.276, val_det_F=1.34e+4, val_det_C=1, val_det_Cinv=0.998, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 89it [01:29,  2.00it/s, det_F=1.43e+4, det_C=0.93, det_Cinv=1.07, r=0.276, val_det_F=1.34e+4, val_det_C=1, val_det_Cinv=0.998, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 89it [01:30,  2.00it/s, det_F=1.6e+4, det_C=0.929, det_Cinv=1.08, r=0.265, val_det_F=1.51e+4, val_det_C=0.997, val_det_Cinv=1, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 90it [01:30,  2.00it/s, det_F=1.6e+4, det_C=0.929, det_Cinv=1.08, r=0.265, val_det_F=1.51e+4, val_det_C=0.997, val_det_Cinv=1, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 90it [01:30,  2.00it/s, det_F=1.8e+4, det_C=0.925, det_Cinv=1.08, r=0.3, val_det_F=1.7e+4, val_det_C=0.992, val_det_Cinv=1.01, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 91it [01:30,  2.01it/s, det_F=1.8e+4, det_C=0.925, det_Cinv=1.08, r=0.3, val_det_F=1.7e+4, val_det_C=0.992, val_det_Cinv=1.01, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 91it [01:31,  2.01it/s, det_F=2.03e+4, det_C=0.921, det_Cinv=1.09, r=0.35, val_det_F=1.91e+4, val_det_C=0.99, val_det_Cinv=1.01, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 92it [01:31,  2.01it/s, det_F=2.03e+4, det_C=0.921, det_Cinv=1.09, r=0.35, val_det_F=1.91e+4, val_det_C=0.99, val_det_Cinv=1.01, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 92it [01:31,  2.01it/s, det_F=2.29e+4, det_C=0.919, det_Cinv=1.09, r=0.366, val_det_F=2.17e+4, val_det_C=0.992, val_det_Cinv=1.01, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 93it [01:31,  2.01it/s, det_F=2.29e+4, det_C=0.919, det_Cinv=1.09, r=0.366, val_det_F=2.17e+4, val_det_C=0.992, val_det_Cinv=1.01, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 93it [01:32,  2.01it/s, det_F=2.58e+4, det_C=0.922, det_Cinv=1.09, r=0.322, val_det_F=2.45e+4, val_det_C=0.996, val_det_Cinv=1, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 94it [01:32,  2.01it/s, det_F=2.58e+4, det_C=0.922, det_Cinv=1.09, r=0.322, val_det_F=2.45e+4, val_det_C=0.996, val_det_Cinv=1, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 94it [01:32,  2.01it/s, det_F=2.92e+4, det_C=0.925, det_Cinv=1.08, r=0.262, val_det_F=2.78e+4, val_det_C=0.998, val_det_Cinv=1, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 95it [01:32,  2.02it/s, det_F=2.92e+4, det_C=0.925, det_Cinv=1.08, r=0.262, val_det_F=2.78e+4, val_det_C=0.998, val_det_Cinv=1, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 95it [01:33,  2.02it/s, det_F=3.3e+4, det_C=0.927, det_Cinv=1.08, r=0.222, val_det_F=3.16e+4, val_det_C=0.995, val_det_Cinv=1.01, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 96it [01:33,  2.01it/s, det_F=3.3e+4, det_C=0.927, det_Cinv=1.08, r=0.222, val_det_F=3.16e+4, val_det_C=0.995, val_det_Cinv=1.01, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 96it [01:33,  2.01it/s, det_F=3.74e+4, det_C=0.924, det_Cinv=1.08, r=0.226, val_det_F=3.59e+4, val_det_C=0.987, val_det_Cinv=1.01, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 97it [01:33,  2.02it/s, det_F=3.74e+4, det_C=0.924, det_Cinv=1.08, r=0.226, val_det_F=3.59e+4, val_det_C=0.987, val_det_Cinv=1.01, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 97it [01:34,  2.02it/s, det_F=4.26e+4, det_C=0.918, det_Cinv=1.09, r=0.283, val_det_F=4.1e+4, val_det_C=0.982, val_det_Cinv=1.02, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 98it [01:34,  2.01it/s, det_F=4.26e+4, det_C=0.918, det_Cinv=1.09, r=0.283, val_det_F=4.1e+4, val_det_C=0.982, val_det_Cinv=1.02, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 98it [01:34,  2.01it/s, det_F=4.86e+4, det_C=0.913, det_Cinv=1.1, r=0.343, val_det_F=4.7e+4, val_det_C=0.981, val_det_Cinv=1.02, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 99it [01:34,  2.02it/s, det_F=4.86e+4, det_C=0.913, det_Cinv=1.1, r=0.343, val_det_F=4.7e+4, val_det_C=0.981, val_det_Cinv=1.02, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 99it [01:35,  2.02it/s, det_F=5.56e+4, det_C=0.913, det_Cinv=1.1, r=0.35, val_det_F=5.4e+4, val_det_C=0.983, val_det_Cinv=1.02, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 100it [01:35,  2.01it/s, det_F=5.56e+4, det_C=0.913, det_Cinv=1.1, r=0.35, val_det_F=5.4e+4, val_det_C=0.983, val_det_Cinv=1.02, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 100it [01:35,  2.01it/s, det_F=6.35e+4, det_C=0.915, det_Cinv=1.09, r=0.312, val_det_F=6.22e+4, val_det_C=0.984, val_det_Cinv=1.02, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 101it [01:35,  1.98it/s, det_F=6.35e+4, det_C=0.915, det_Cinv=1.09, r=0.312, val_det_F=6.22e+4, val_det_C=0.984, val_det_Cinv=1.02, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 101it [01:36,  1.98it/s, det_F=7.27e+4, det_C=0.916, det_Cinv=1.09, r=0.3, val_det_F=7.16e+4, val_det_C=0.98, val_det_Cinv=1.02, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 102it [01:36,  1.95it/s, det_F=7.27e+4, det_C=0.916, det_Cinv=1.09, r=0.3, val_det_F=7.16e+4, val_det_C=0.98, val_det_Cinv=1.02, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 102it [01:36,  1.95it/s, det_F=8.34e+4, det_C=0.913, det_Cinv=1.1, r=0.348, val_det_F=8.26e+4, val_det_C=0.972, val_det_Cinv=1.03, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 103it [01:36,  1.98it/s, det_F=8.34e+4, det_C=0.913, det_Cinv=1.1, r=0.348, val_det_F=8.26e+4, val_det_C=0.972, val_det_Cinv=1.03, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 103it [01:37,  1.98it/s, det_F=9.6e+4, det_C=0.907, det_Cinv=1.1, r=0.435, val_det_F=9.55e+4, val_det_C=0.968, val_det_Cinv=1.03, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 104it [01:37,  1.99it/s, det_F=9.6e+4, det_C=0.907, det_Cinv=1.1, r=0.435, val_det_F=9.55e+4, val_det_C=0.968, val_det_Cinv=1.03, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 104it [01:37,  1.99it/s, det_F=1.1e+5, det_C=0.904, det_Cinv=1.11, r=0.469, val_det_F=1.11e+5, val_det_C=0.968, val_det_Cinv=1.03, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 105it [01:37,  1.99it/s, det_F=1.1e+5, det_C=0.904, det_Cinv=1.11, r=0.469, val_det_F=1.11e+5, val_det_C=0.968, val_det_Cinv=1.03, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 105it [01:38,  1.99it/s, det_F=1.27e+5, det_C=0.904, det_Cinv=1.11, r=0.413, val_det_F=1.28e+5, val_det_C=0.967, val_det_Cinv=1.03, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 106it [01:38,  2.00it/s, det_F=1.27e+5, det_C=0.904, det_Cinv=1.11, r=0.413, val_det_F=1.28e+5, val_det_C=0.967, val_det_Cinv=1.03, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 106it [01:38,  2.00it/s, det_F=1.46e+5, det_C=0.905, det_Cinv=1.11, r=0.369, val_det_F=1.49e+5, val_det_C=0.964, val_det_Cinv=1.04, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 107it [01:38,  2.00it/s, det_F=1.46e+5, det_C=0.905, det_Cinv=1.11, r=0.369, val_det_F=1.49e+5, val_det_C=0.964, val_det_Cinv=1.04, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 107it [01:39,  2.00it/s, det_F=1.69e+5, det_C=0.903, det_Cinv=1.11, r=0.373, val_det_F=1.73e+5, val_det_C=0.958, val_det_Cinv=1.04, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 108it [01:39,  2.00it/s, det_F=1.69e+5, det_C=0.903, det_Cinv=1.11, r=0.373, val_det_F=1.73e+5, val_det_C=0.958, val_det_Cinv=1.04, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 108it [01:39,  2.00it/s, det_F=1.96e+5, det_C=0.899, det_Cinv=1.11, r=0.43, val_det_F=2.01e+5, val_det_C=0.952, val_det_Cinv=1.05, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 109it [01:39,  2.00it/s, det_F=1.96e+5, det_C=0.899, det_Cinv=1.11, r=0.43, val_det_F=2.01e+5, val_det_C=0.952, val_det_Cinv=1.05, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 109it [01:40,  2.00it/s, det_F=2.27e+5, det_C=0.895, det_Cinv=1.12, r=0.488, val_det_F=2.34e+5, val_det_C=0.949, val_det_Cinv=1.05, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 110it [01:40,  2.00it/s, det_F=2.27e+5, det_C=0.895, det_Cinv=1.12, r=0.488, val_det_F=2.34e+5, val_det_C=0.949, val_det_Cinv=1.05, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 110it [01:40,  2.00it/s, det_F=2.64e+5, det_C=0.894, det_Cinv=1.12, r=0.465, val_det_F=2.72e+5, val_det_C=0.949, val_det_Cinv=1.05, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 111it [01:40,  2.01it/s, det_F=2.64e+5, det_C=0.894, det_Cinv=1.12, r=0.465, val_det_F=2.72e+5, val_det_C=0.949, val_det_Cinv=1.05, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 111it [01:41,  2.01it/s, det_F=3.06e+5, det_C=0.895, det_Cinv=1.12, r=0.393, val_det_F=3.17e+5, val_det_C=0.949, val_det_Cinv=1.05, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 112it [01:41,  2.01it/s, det_F=3.06e+5, det_C=0.895, det_Cinv=1.12, r=0.393, val_det_F=3.17e+5, val_det_C=0.949, val_det_Cinv=1.05, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 112it [01:41,  2.01it/s, det_F=3.55e+5, det_C=0.897, det_Cinv=1.12, r=0.326, val_det_F=3.71e+5, val_det_C=0.948, val_det_Cinv=1.06, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 113it [01:41,  2.02it/s, det_F=3.55e+5, det_C=0.897, det_Cinv=1.12, r=0.326, val_det_F=3.71e+5, val_det_C=0.948, val_det_Cinv=1.06, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 113it [01:42,  2.02it/s, det_F=4.14e+5, det_C=0.897, det_Cinv=1.12, r=0.311, val_det_F=4.34e+5, val_det_C=0.943, val_det_Cinv=1.06, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 114it [01:42,  2.01it/s, det_F=4.14e+5, det_C=0.897, det_Cinv=1.12, r=0.311, val_det_F=4.34e+5, val_det_C=0.943, val_det_Cinv=1.06, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 114it [01:42,  2.01it/s, det_F=4.83e+5, det_C=0.894, det_Cinv=1.12, r=0.353, val_det_F=5.09e+5, val_det_C=0.936, val_det_Cinv=1.07, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 115it [01:42,  2.02it/s, det_F=4.83e+5, det_C=0.894, det_Cinv=1.12, r=0.353, val_det_F=5.09e+5, val_det_C=0.936, val_det_Cinv=1.07, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 115it [01:43,  2.02it/s, det_F=5.65e+5, det_C=0.889, det_Cinv=1.13, r=0.46, val_det_F=5.97e+5, val_det_C=0.932, val_det_Cinv=1.07, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 116it [01:43,  2.02it/s, det_F=5.65e+5, det_C=0.889, det_Cinv=1.13, r=0.46, val_det_F=5.97e+5, val_det_C=0.932, val_det_Cinv=1.07, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 116it [01:43,  2.02it/s, det_F=6.62e+5, det_C=0.886, det_Cinv=1.13, r=0.535, val_det_F=7e+5, val_det_C=0.933, val_det_Cinv=1.07, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 117it [01:43,  2.02it/s, det_F=6.62e+5, det_C=0.886, det_Cinv=1.13, r=0.535, val_det_F=7e+5, val_det_C=0.933, val_det_Cinv=1.07, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 117it [01:44,  2.02it/s, det_F=7.73e+5, det_C=0.888, det_Cinv=1.13, r=0.471, val_det_F=8.2e+5, val_det_C=0.936, val_det_Cinv=1.07, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 118it [01:44,  2.02it/s, det_F=7.73e+5, det_C=0.888, det_Cinv=1.13, r=0.471, val_det_F=8.2e+5, val_det_C=0.936, val_det_Cinv=1.07, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 118it [01:44,  2.02it/s, det_F=9.03e+5, det_C=0.891, det_Cinv=1.12, r=0.392, val_det_F=9.63e+5, val_det_C=0.934, val_det_Cinv=1.07, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 119it [01:44,  2.01it/s, det_F=9.03e+5, det_C=0.891, det_Cinv=1.12, r=0.392, val_det_F=9.63e+5, val_det_C=0.934, val_det_Cinv=1.07, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 119it [01:45,  2.01it/s, det_F=1.06e+6, det_C=0.891, det_Cinv=1.12, r=0.391, val_det_F=1.13e+6, val_det_C=0.93, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 120it [01:45,  2.02it/s, det_F=1.06e+6, det_C=0.891, det_Cinv=1.12, r=0.391, val_det_F=1.13e+6, val_det_C=0.93, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 120it [01:45,  2.02it/s, det_F=1.24e+6, det_C=0.888, det_Cinv=1.13, r=0.449, val_det_F=1.33e+6, val_det_C=0.928, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 121it [01:45,  2.02it/s, det_F=1.24e+6, det_C=0.888, det_Cinv=1.13, r=0.449, val_det_F=1.33e+6, val_det_C=0.928, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 121it [01:46,  2.02it/s, det_F=1.46e+6, det_C=0.886, det_Cinv=1.13, r=0.499, val_det_F=1.56e+6, val_det_C=0.928, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 122it [01:46,  2.02it/s, det_F=1.46e+6, det_C=0.886, det_Cinv=1.13, r=0.499, val_det_F=1.56e+6, val_det_C=0.928, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 122it [01:46,  2.02it/s, det_F=1.71e+6, det_C=0.886, det_Cinv=1.13, r=0.518, val_det_F=1.84e+6, val_det_C=0.927, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 123it [01:46,  2.00it/s, det_F=1.71e+6, det_C=0.886, det_Cinv=1.13, r=0.518, val_det_F=1.84e+6, val_det_C=0.927, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 123it [01:47,  2.00it/s, det_F=2e+6, det_C=0.886, det_Cinv=1.13, r=0.512, val_det_F=2.16e+6, val_det_C=0.925, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 124it [01:47,  2.00it/s, det_F=2e+6, det_C=0.886, det_Cinv=1.13, r=0.512, val_det_F=2.16e+6, val_det_C=0.925, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 124it [01:47,  2.00it/s, det_F=2.35e+6, det_C=0.885, det_Cinv=1.13, r=0.518, val_det_F=2.53e+6, val_det_C=0.924, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 125it [01:47,  2.00it/s, det_F=2.35e+6, det_C=0.885, det_Cinv=1.13, r=0.518, val_det_F=2.53e+6, val_det_C=0.924, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 125it [01:48,  2.00it/s, det_F=2.75e+6, det_C=0.884, det_Cinv=1.13, r=0.52, val_det_F=2.97e+6, val_det_C=0.925, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 126it [01:48,  1.99it/s, det_F=2.75e+6, det_C=0.884, det_Cinv=1.13, r=0.52, val_det_F=2.97e+6, val_det_C=0.925, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 126it [01:48,  1.99it/s, det_F=3.22e+6, det_C=0.886, det_Cinv=1.13, r=0.48, val_det_F=3.48e+6, val_det_C=0.925, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 127it [01:48,  2.00it/s, det_F=3.22e+6, det_C=0.886, det_Cinv=1.13, r=0.48, val_det_F=3.48e+6, val_det_C=0.925, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 127it [01:49,  2.00it/s, det_F=3.77e+6, det_C=0.886, det_Cinv=1.13, r=0.492, val_det_F=4.08e+6, val_det_C=0.921, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 128it [01:49,  2.00it/s, det_F=3.77e+6, det_C=0.886, det_Cinv=1.13, r=0.492, val_det_F=4.08e+6, val_det_C=0.921, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 128it [01:49,  2.00it/s, det_F=4.41e+6, det_C=0.883, det_Cinv=1.13, r=0.57, val_det_F=4.78e+6, val_det_C=0.918, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 129it [01:49,  2.00it/s, det_F=4.41e+6, det_C=0.883, det_Cinv=1.13, r=0.57, val_det_F=4.78e+6, val_det_C=0.918, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 129it [01:50,  2.00it/s, det_F=5.15e+6, det_C=0.881, det_Cinv=1.14, r=0.611, val_det_F=5.58e+6, val_det_C=0.921, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 130it [01:50,  1.99it/s, det_F=5.15e+6, det_C=0.881, det_Cinv=1.14, r=0.611, val_det_F=5.58e+6, val_det_C=0.921, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 130it [01:50,  1.99it/s, det_F=6e+6, det_C=0.883, det_Cinv=1.13, r=0.535, val_det_F=6.5e+6, val_det_C=0.923, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 131it [01:50,  1.99it/s, det_F=6e+6, det_C=0.883, det_Cinv=1.13, r=0.535, val_det_F=6.5e+6, val_det_C=0.923, val_det_Cinv=1.08, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 131it [01:51,  1.99it/s, det_F=6.99e+6, det_C=0.885, det_Cinv=1.13, r=0.513, val_det_F=7.6e+6, val_det_C=0.918, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 132it [01:51,  2.00it/s, det_F=6.99e+6, det_C=0.885, det_Cinv=1.13, r=0.513, val_det_F=7.6e+6, val_det_C=0.918, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 132it [01:51,  2.00it/s, det_F=8.15e+6, det_C=0.881, det_Cinv=1.13, r=0.615, val_det_F=8.86e+6, val_det_C=0.916, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 133it [01:51,  2.00it/s, det_F=8.15e+6, det_C=0.881, det_Cinv=1.13, r=0.615, val_det_F=8.86e+6, val_det_C=0.916, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 133it [01:52,  2.00it/s, det_F=9.48e+6, det_C=0.879, det_Cinv=1.14, r=0.685, val_det_F=1.03e+7, val_det_C=0.92, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 134it [01:52,  2.01it/s, det_F=9.48e+6, det_C=0.879, det_Cinv=1.14, r=0.685, val_det_F=1.03e+7, val_det_C=0.92, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 134it [01:52,  2.01it/s, det_F=1.1e+7, det_C=0.883, det_Cinv=1.13, r=0.575, val_det_F=1.19e+7, val_det_C=0.92, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 135it [01:52,  2.01it/s, det_F=1.1e+7, det_C=0.883, det_Cinv=1.13, r=0.575, val_det_F=1.19e+7, val_det_C=0.92, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 135it [01:53,  2.01it/s, det_F=1.27e+7, det_C=0.883, det_Cinv=1.13, r=0.58, val_det_F=1.38e+7, val_det_C=0.917, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 136it [01:53,  2.02it/s, det_F=1.27e+7, det_C=0.883, det_Cinv=1.13, r=0.58, val_det_F=1.38e+7, val_det_C=0.917, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 136it [01:53,  2.02it/s, det_F=1.47e+7, det_C=0.88, det_Cinv=1.14, r=0.679, val_det_F=1.6e+7, val_det_C=0.917, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 137it [01:53,  2.02it/s, det_F=1.47e+7, det_C=0.88, det_Cinv=1.14, r=0.679, val_det_F=1.6e+7, val_det_C=0.917, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 137it [01:54,  2.02it/s, det_F=1.7e+7, det_C=0.881, det_Cinv=1.14, r=0.671, val_det_F=1.84e+7, val_det_C=0.919, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 138it [01:54,  2.01it/s, det_F=1.7e+7, det_C=0.881, det_Cinv=1.14, r=0.671, val_det_F=1.84e+7, val_det_C=0.919, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 138it [01:54,  2.01it/s, det_F=1.96e+7, det_C=0.882, det_Cinv=1.13, r=0.634, val_det_F=2.12e+7, val_det_C=0.917, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 139it [01:54,  2.01it/s, det_F=1.96e+7, det_C=0.882, det_Cinv=1.13, r=0.634, val_det_F=2.12e+7, val_det_C=0.917, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 139it [01:55,  2.01it/s, det_F=2.25e+7, det_C=0.881, det_Cinv=1.14, r=0.669, val_det_F=2.43e+7, val_det_C=0.917, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 140it [01:55,  2.01it/s, det_F=2.25e+7, det_C=0.881, det_Cinv=1.14, r=0.669, val_det_F=2.43e+7, val_det_C=0.917, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 140it [01:55,  2.01it/s, det_F=2.58e+7, det_C=0.881, det_Cinv=1.13, r=0.648, val_det_F=2.79e+7, val_det_C=0.916, val_det_Cinv=1.09, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1046it [09:25,  2.02it/s, det_F=1.05e+9, det_C=0.885, det_Cinv=1.13, r=0.628, val_det_F=1.15e+9, val_det_C=0.823, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1047it [09:25,  2.02it/s, det_F=1.05e+9, det_C=0.885, det_Cinv=1.13, r=0.628, val_det_F=1.15e+9, val_det_C=0.823, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1047it [09:25,  2.02it/s, det_F=1.06e+9, det_C=0.885, det_Cinv=1.13, r=0.622, val_det_F=1.16e+9, val_det_C=0.823, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1048it [09:25,  2.02it/s, det_F=1.06e+9, det_C=0.885, det_Cinv=1.13, r=0.622, val_det_F=1.16e+9, val_det_C=0.823, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1048it [09:26,  2.02it/s, det_F=1.07e+9, det_C=0.884, det_Cinv=1.13, r=0.617, val_det_F=1.18e+9, val_det_C=0.823, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1049it [09:26,  2.01it/s, det_F=1.07e+9, det_C=0.884, det_Cinv=1.13, r=0.617, val_det_F=1.18e+9, val_det_C=0.823, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1049it [09:26,  2.01it/s, det_F=1.08e+9, det_C=0.884, det_Cinv=1.13, r=0.608, val_det_F=1.19e+9, val_det_C=0.823, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1050it [09:26,  2.01it/s, det_F=1.08e+9, det_C=0.884, det_Cinv=1.13, r=0.608, val_det_F=1.19e+9, val_det_C=0.823, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1050it [09:27,  2.01it/s, det_F=1.1e+9, det_C=0.884, det_Cinv=1.13, r=0.609, val_det_F=1.21e+9, val_det_C=0.823, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1051it [09:27,  2.02it/s, det_F=1.1e+9, det_C=0.884, det_Cinv=1.13, r=0.609, val_det_F=1.21e+9, val_det_C=0.823, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1051it [09:27,  2.02it/s, det_F=1.11e+9, det_C=0.884, det_Cinv=1.13, r=0.601, val_det_F=1.22e+9, val_det_C=0.823, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1052it [09:27,  2.02it/s, det_F=1.11e+9, det_C=0.884, det_Cinv=1.13, r=0.601, val_det_F=1.22e+9, val_det_C=0.823, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1052it [09:28,  2.02it/s, det_F=1.13e+9, det_C=0.884, det_Cinv=1.13, r=0.596, val_det_F=1.24e+9, val_det_C=0.822, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1053it [09:28,  2.01it/s, det_F=1.13e+9, det_C=0.884, det_Cinv=1.13, r=0.596, val_det_F=1.24e+9, val_det_C=0.822, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1053it [09:28,  2.01it/s, det_F=1.14e+9, det_C=0.883, det_Cinv=1.13, r=0.609, val_det_F=1.25e+9, val_det_C=0.822, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1054it [09:28,  2.02it/s, det_F=1.14e+9, det_C=0.883, det_Cinv=1.13, r=0.609, val_det_F=1.25e+9, val_det_C=0.822, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1054it [09:29,  2.02it/s, det_F=1.16e+9, det_C=0.882, det_Cinv=1.13, r=0.617, val_det_F=1.27e+9, val_det_C=0.822, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1055it [09:29,  2.02it/s, det_F=1.16e+9, det_C=0.882, det_Cinv=1.13, r=0.617, val_det_F=1.27e+9, val_det_C=0.822, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1055it [09:29,  2.02it/s, det_F=1.17e+9, det_C=0.882, det_Cinv=1.13, r=0.63, val_det_F=1.28e+9, val_det_C=0.822, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1056it [09:29,  2.02it/s, det_F=1.17e+9, det_C=0.882, det_Cinv=1.13, r=0.63, val_det_F=1.28e+9, val_det_C=0.822, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1056it [09:30,  2.02it/s, det_F=1.19e+9, det_C=0.882, det_Cinv=1.13, r=0.639, val_det_F=1.3e+9, val_det_C=0.823, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1057it [09:30,  2.02it/s, det_F=1.19e+9, det_C=0.882, det_Cinv=1.13, r=0.639, val_det_F=1.3e+9, val_det_C=0.823, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1057it [09:30,  2.02it/s, det_F=1.2e+9, det_C=0.883, det_Cinv=1.13, r=0.635, val_det_F=1.32e+9, val_det_C=0.824, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1058it [09:30,  2.02it/s, det_F=1.2e+9, det_C=0.883, det_Cinv=1.13, r=0.635, val_det_F=1.32e+9, val_det_C=0.824, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1058it [09:31,  2.02it/s, det_F=1.22e+9, det_C=0.883, det_Cinv=1.13, r=0.629, val_det_F=1.33e+9, val_det_C=0.825, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1059it [09:31,  2.02it/s, det_F=1.22e+9, det_C=0.883, det_Cinv=1.13, r=0.629, val_det_F=1.33e+9, val_det_C=0.825, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1059it [09:31,  2.02it/s, det_F=1.23e+9, det_C=0.884, det_Cinv=1.13, r=0.632, val_det_F=1.35e+9, val_det_C=0.825, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1060it [09:31,  2.02it/s, det_F=1.23e+9, det_C=0.884, det_Cinv=1.13, r=0.632, val_det_F=1.35e+9, val_det_C=0.825, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1060it [09:32,  2.02it/s, det_F=1.25e+9, det_C=0.884, det_Cinv=1.13, r=0.625, val_det_F=1.37e+9, val_det_C=0.825, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1061it [09:32,  2.02it/s, det_F=1.25e+9, det_C=0.884, det_Cinv=1.13, r=0.625, val_det_F=1.37e+9, val_det_C=0.825, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1061it [09:32,  2.02it/s, det_F=1.27e+9, det_C=0.884, det_Cinv=1.13, r=0.65, val_det_F=1.38e+9, val_det_C=0.826, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1062it [09:32,  2.02it/s, det_F=1.27e+9, det_C=0.884, det_Cinv=1.13, r=0.65, val_det_F=1.38e+9, val_det_C=0.826, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1062it [09:33,  2.02it/s, det_F=1.28e+9, det_C=0.884, det_Cinv=1.13, r=0.637, val_det_F=1.4e+9, val_det_C=0.826, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1063it [09:33,  2.02it/s, det_F=1.28e+9, det_C=0.884, det_Cinv=1.13, r=0.637, val_det_F=1.4e+9, val_det_C=0.826, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1063it [09:33,  2.02it/s, det_F=1.3e+9, det_C=0.883, det_Cinv=1.13, r=0.647, val_det_F=1.42e+9, val_det_C=0.826, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1064it [09:33,  2.02it/s, det_F=1.3e+9, det_C=0.883, det_Cinv=1.13, r=0.647, val_det_F=1.42e+9, val_det_C=0.826, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1064it [09:34,  2.02it/s, det_F=1.32e+9, det_C=0.884, det_Cinv=1.13, r=0.631, val_det_F=1.44e+9, val_det_C=0.827, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1065it [09:34,  2.02it/s, det_F=1.32e+9, det_C=0.884, det_Cinv=1.13, r=0.631, val_det_F=1.44e+9, val_det_C=0.827, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1065it [09:34,  2.02it/s, det_F=1.33e+9, det_C=0.884, det_Cinv=1.13, r=0.615, val_det_F=1.45e+9, val_det_C=0.826, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1066it [09:34,  2.02it/s, det_F=1.33e+9, det_C=0.884, det_Cinv=1.13, r=0.615, val_det_F=1.45e+9, val_det_C=0.826, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1066it [09:35,  2.02it/s, det_F=1.35e+9, det_C=0.883, det_Cinv=1.13, r=0.631, val_det_F=1.47e+9, val_det_C=0.827, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1067it [09:35,  2.02it/s, det_F=1.35e+9, det_C=0.883, det_Cinv=1.13, r=0.631, val_det_F=1.47e+9, val_det_C=0.827, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1067it [09:35,  2.02it/s, det_F=1.37e+9, det_C=0.883, det_Cinv=1.13, r=0.608, val_det_F=1.49e+9, val_det_C=0.826, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1068it [09:35,  2.02it/s, det_F=1.37e+9, det_C=0.883, det_Cinv=1.13, r=0.608, val_det_F=1.49e+9, val_det_C=0.826, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1068it [09:36,  2.02it/s, det_F=1.39e+9, det_C=0.881, det_Cinv=1.13, r=0.656, val_det_F=1.51e+9, val_det_C=0.827, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1069it [09:36,  2.02it/s, det_F=1.39e+9, det_C=0.881, det_Cinv=1.13, r=0.656, val_det_F=1.51e+9, val_det_C=0.827, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1069it [09:36,  2.02it/s, det_F=1.41e+9, det_C=0.882, det_Cinv=1.13, r=0.602, val_det_F=1.53e+9, val_det_C=0.826, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1070it [09:36,  2.02it/s, det_F=1.41e+9, det_C=0.882, det_Cinv=1.13, r=0.602, val_det_F=1.53e+9, val_det_C=0.826, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1070it [09:37,  2.02it/s, det_F=1.43e+9, det_C=0.88, det_Cinv=1.14, r=0.678, val_det_F=1.55e+9, val_det_C=0.829, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1071it [09:37,  2.02it/s, det_F=1.43e+9, det_C=0.88, det_Cinv=1.14, r=0.678, val_det_F=1.55e+9, val_det_C=0.829, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1071it [09:37,  2.02it/s, det_F=1.44e+9, det_C=0.884, det_Cinv=1.13, r=0.55, val_det_F=1.58e+9, val_det_C=0.825, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1072it [09:37,  2.02it/s, det_F=1.44e+9, det_C=0.884, det_Cinv=1.13, r=0.55, val_det_F=1.58e+9, val_det_C=0.825, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1072it [09:38,  2.02it/s, det_F=1.47e+9, det_C=0.879, det_Cinv=1.14, r=0.748, val_det_F=1.59e+9, val_det_C=0.834, val_det_Cinv=1.2, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1073it [09:38,  2.02it/s, det_F=1.47e+9, det_C=0.879, det_Cinv=1.14, r=0.748, val_det_F=1.59e+9, val_det_C=0.834, val_det_Cinv=1.2, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1073it [09:38,  2.02it/s, det_F=1.48e+9, det_C=0.888, det_Cinv=1.13, r=0.45, val_det_F=1.62e+9, val_det_C=0.825, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1074it [09:38,  2.02it/s, det_F=1.48e+9, det_C=0.888, det_Cinv=1.13, r=0.45, val_det_F=1.62e+9, val_det_C=0.825, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1074it [09:39,  2.02it/s, det_F=1.51e+9, det_C=0.878, det_Cinv=1.14, r=0.837, val_det_F=1.63e+9, val_det_C=0.836, val_det_Cinv=1.2, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1075it [09:39,  2.03it/s, det_F=1.51e+9, det_C=0.878, det_Cinv=1.14, r=0.837, val_det_F=1.63e+9, val_det_C=0.836, val_det_Cinv=1.2, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1075it [09:39,  2.03it/s, det_F=1.52e+9, det_C=0.889, det_Cinv=1.12, r=0.452, val_det_F=1.67e+9, val_det_C=0.828, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1076it [09:39,  2.02it/s, det_F=1.52e+9, det_C=0.889, det_Cinv=1.12, r=0.452, val_det_F=1.67e+9, val_det_C=0.828, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1076it [09:40,  2.02it/s, det_F=1.56e+9, det_C=0.88, det_Cinv=1.14, r=0.725, val_det_F=1.69e+9, val_det_C=0.83, val_det_Cinv=1.2, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1077it [09:40,  2.02it/s, det_F=1.56e+9, det_C=0.88, det_Cinv=1.14, r=0.725, val_det_F=1.69e+9, val_det_C=0.83, val_det_Cinv=1.2, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1077it [09:40,  2.02it/s, det_F=1.58e+9, det_C=0.882, det_Cinv=1.13, r=0.672, val_det_F=1.7e+9, val_det_C=0.836, val_det_Cinv=1.2, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1078it [09:40,  2.02it/s, det_F=1.58e+9, det_C=0.882, det_Cinv=1.13, r=0.672, val_det_F=1.7e+9, val_det_C=0.836, val_det_Cinv=1.2, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1078it [09:41,  2.02it/s, det_F=1.59e+9, det_C=0.888, det_Cinv=1.13, r=0.476, val_det_F=1.74e+9, val_det_C=0.827, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1079it [09:41,  2.02it/s, det_F=1.59e+9, det_C=0.888, det_Cinv=1.13, r=0.476, val_det_F=1.74e+9, val_det_C=0.827, val_det_Cinv=1.21, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1079it [09:41,  2.02it/s, det_F=1.63e+9, det_C=0.878, det_Cinv=1.14, r=0.862, val_det_F=1.74e+9, val_det_C=0.842, val_det_Cinv=1.19, patience=1]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1080it [09:41,  2.02it/s, det_F=1.63e+9, det_C=0.878, det_Cinv=1.14, r=0.862, val_det_F=1.74e+9, val_det_C=0.842, val_det_Cinv=1.19, patience=1]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1080it [09:42,  2.02it/s, det_F=1.63e+9, det_C=0.893, det_Cinv=1.12, r=0.407, val_det_F=1.78e+9, val_det_C=0.831, val_det_Cinv=1.2, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1081it [09:42,  2.02it/s, det_F=1.63e+9, det_C=0.893, det_Cinv=1.12, r=0.407, val_det_F=1.78e+9, val_det_C=0.831, val_det_Cinv=1.2, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1081it [09:42,  2.02it/s, det_F=1.67e+9, det_C=0.881, det_Cinv=1.14, r=0.662, val_det_F=1.83e+9, val_det_C=0.823, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1082it [09:42,  2.02it/s, det_F=1.67e+9, det_C=0.881, det_Cinv=1.14, r=0.662, val_det_F=1.83e+9, val_det_C=0.823, val_det_Cinv=1.22, patience=0]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1082it [09:43,  2.02it/s, det_F=1.71e+9, det_C=0.871, det_Cinv=1.15, r=1.36, val_det_F=1.74e+9, val_det_C=0.885, val_det_Cinv=1.13, patience=1]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1083it [09:43,  2.03it/s, det_F=1.71e+9, det_C=0.871, det_Cinv=1.15, r=1.36, val_det_F=1.74e+9, val_det_C=0.885, val_det_Cinv=1.13, patience=1]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1083it [09:43,  2.03it/s, det_F=1.63e+9, det_C=0.938, det_Cinv=1.07, r=5.27, val_det_F=1.61e+9, val_det_C=0.841, val_det_Cinv=1.19, patience=2]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1084it [09:43,  2.03it/s, det_F=1.63e+9, det_C=0.938, det_Cinv=1.07, r=5.27, val_det_F=1.61e+9, val_det_C=0.841, val_det_Cinv=1.19, patience=2]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1084it [09:44,  2.03it/s, det_F=1.56e+9, det_C=0.862, det_Cinv=1.16, r=10, val_det_F=6.86e+8, val_det_C=1.35, val_det_Cinv=0.741, patience=3]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1085it [09:44,  2.03it/s, det_F=1.56e+9, det_C=0.862, det_Cinv=1.16, r=10, val_det_F=6.86e+8, val_det_C=1.35, val_det_Cinv=0.741, patience=3]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1085it [09:44,  2.03it/s, det_F=6.43e+8, det_C=1.44, det_Cinv=0.695, r=10, val_det_F=1.21e+9, val_det_C=1.08, val_det_Cinv=0.929, patience=4]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1086it [09:44,  2.03it/s, det_F=6.43e+8, det_C=1.44, det_Cinv=0.695, r=10, val_det_F=1.21e+9, val_det_C=1.08, val_det_Cinv=0.929, patience=4]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1086it [09:45,  2.03it/s, det_F=1.15e+9, det_C=1.13, det_Cinv=0.882, r=10, val_det_F=6.81e+8, val_det_C=1.59, val_det_Cinv=0.629, patience=5]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1087it [09:45,  2.03it/s, det_F=1.15e+9, det_C=1.13, det_Cinv=0.882, r=10, val_det_F=6.81e+8, val_det_C=1.59, val_det_Cinv=0.629, patience=5]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1087it [09:45,  2.03it/s, det_F=6.58e+8, det_C=1.62, det_Cinv=0.617, r=10, val_det_F=4.2e+8, val_det_C=1.74, val_det_Cinv=0.575, patience=6]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1088it [09:45,  2.03it/s, det_F=6.58e+8, det_C=1.62, det_Cinv=0.617, r=10, val_det_F=4.2e+8, val_det_C=1.74, val_det_Cinv=0.575, patience=6]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1088it [09:46,  2.03it/s, det_F=4.1e+8, det_C=1.76, det_Cinv=0.568, r=10, val_det_F=3.47e+8, val_det_C=1.3, val_det_Cinv=0.772, patience=7]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1089it [09:46,  2.02it/s, det_F=4.1e+8, det_C=1.76, det_Cinv=0.568, r=10, val_det_F=3.47e+8, val_det_C=1.3, val_det_Cinv=0.772, patience=7]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1089it [09:46,  2.02it/s, det_F=3.49e+8, det_C=1.28, det_Cinv=0.78, r=10, val_det_F=2.36e+8, val_det_C=1.05, val_det_Cinv=0.95, patience=8]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1090it [09:46,  2.02it/s, det_F=3.49e+8, det_C=1.28, det_Cinv=0.78, r=10, val_det_F=2.36e+8, val_det_C=1.05, val_det_Cinv=0.95, patience=8]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1090it [09:47,  2.02it/s, det_F=2.38e+8, det_C=1.04, det_Cinv=0.959, r=10, val_det_F=1.62e+8, val_det_C=0.98, val_det_Cinv=1.02, patience=9]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1091it [09:47,  2.02it/s, det_F=2.38e+8, det_C=1.04, det_Cinv=0.959, r=10, val_det_F=1.62e+8, val_det_C=0.98, val_det_Cinv=1.02, patience=9]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1091it [09:47,  2.02it/s, det_F=1.62e+8, det_C=0.978, det_Cinv=1.02, r=10, val_det_F=1.19e+8, val_det_C=0.996, val_det_Cinv=1, patience=10]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1092it [09:47,  2.02it/s, det_F=1.62e+8, det_C=0.978, det_Cinv=1.02, r=10, val_det_F=1.19e+8, val_det_C=0.996, val_det_Cinv=1, patience=10]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1092it [09:48,  2.02it/s, det_F=1.18e+8, det_C=1, det_Cinv=0.999, r=10, val_det_F=9.09e+7, val_det_C=1.07, val_det_Cinv=0.936, patience=11]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Iterations: 1093it [09:48,  2.03it/s, det_F=1.18e+8, det_C=1, det_Cinv=0.999, r=10, val_det_F=9.09e+7, val_det_C=1.07, val_det_Cinv=0.936, patience=11]
# Reached 10 steps without increasing val_det_F. Resetting weights to iteration 1081.

# %%
imnn.plot(known_det_fisher=15.)

# %%
generator = GenerateSpiralData(input_shape=(300,))

θ_target = np.array([1.1, 0.2])[np.newaxis, :]
target_data = generator.simulator(
    parameters=θ_target,
    seed=37,
    simulator_args={"input_shape": generator.input_shape})

generator.plot_data(target_data, label="Observed data")
# Out:
# No handles with labels found to put in legend.
# (300, 1)
# (<Figure size 360x288 with 1 Axes>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x1553b4382590>)

# %%
prior = tfd.Blockwise([tfd.Uniform(0., 10.),
                       tfd.Uniform(0.1, 10.)])

# %%
GA = LFI.GaussianApproximation(
    target_data=target_data.astype(np.float32), 
    prior=prior, 
    Fisher=imnn.F,
    get_estimate=imnn.get_estimate,
    labels=[r"$\theta$", r"$\Sigma_\theta$"])

GA.plot_Fisher(figsize=(5, 5));

# %%
θ_target[0][1]
# Out:
# 0.2

# %%
ax = GA.plot(
    gridsize=(1000, 1000),
    color="C2",
    label="Gaussian approximation");

ax[0][0].plot(np.ones(10)*θ_target[0][0], np.linspace(-0.001,0.1, 10), linestyle='--')
ax[1][0].plot(np.ones(10)*θ_target[0][0], np.linspace(-0.001,0.1, 10), linestyle='--')

#ax[0][1].plot(np.ones(10)*np.pi/2, np.linspace(-0.001,0.05, 10))
ax[1][1].plot(np.ones(10)*θ_target[0][1], np.linspace(-0.001,0.1, 10), linestyle='--')

# %%
# run ABC computation
ABC = LFI.ApproximateBayesianComputation(
    target_data=target_data.astype(np.float32), 
    prior=prior, 
    Fisher=imnn.F,
    get_estimate=imnn.get_estimate,
    simulator=lambda x : SN.simulator(
        x, None, {"input_shape": SN.input_shape}),
    labels=[r"$\theta$", r"$\Sigma_\theta$"])

# %%
ax = GA.plot(
    gridsize=(1000, 1000),
    color="C2",
    label="Gaussian approximation");
ABC.plot(
    ϵ=0.5,
    accepted=2000,
    draws=100000,
    ax=ax,
    color="C1",
    label="ABC posterior at ϵ={}".format(0.5),
    smoothing=0,
    bins=50);


ax[0][0].plot(np.ones(10)*θ_target[0][0], np.linspace(-0.001,0.1, 10), linestyle='--', color='k')
ax[1][0].plot(np.ones(10)*θ_target[0][0], np.linspace(-0.001,0.1, 10), linestyle='--', color='k')

ax[1][1].plot(np.ones(10)*θ_target[0][1], np.linspace(-0.001,1., 10), linestyle='--', color='k')
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-386-b4cc53a5ee5d> in <module>
#      11     label="ABC posterior at ϵ={}".format(0.5),
#      12     smoothing=0,
# ---> 13     bins=50);
#      14
#      15
#
# ~/repositories/imnn/IMNN/LFI/LFI.py in plot(self, smoothing, **kwargs)
#     446
#     447     def plot(self, smoothing=None, **kwargs):
# --> 448         posterior = self.posterior(**kwargs)
#     449         return self.triangle_plot(posterior, grid=self.grid, meshgrid=False,smoothing=smoothing, **kwargs)
#     450
#
# ~/repositories/imnn/IMNN/LFI/LFI.py in posterior(self, bins, ranges, **kwargs)
#     424
#     425     def posterior(self, bins=25, ranges=None, **kwargs):
# --> 426         self.setup_points(**kwargs)
#     427         if ranges is None:
#     428             low_ind = np.argwhere(self.prior.low == -np.inf)
#
# ~/repositories/imnn/IMNN/LFI/LFI.py in setup_points(self, ε, draws, accepted, at_once, save_sims, tqdm_notebook, **kwargs)
#     452         if ϵ is not None:
#     453             if accepted is not None:
# --> 454                 self.get_min_accepted(ϵ=ϵ, accepted=accepted, min_draws=draws, at_once=at_once, save_sims=save_sims, tqdm_notebook=tqdm_notebook)
#     455             elif draws is not None:
#     456                 self.__call__(draws=draws, at_once=at_once,
#
# ~/repositories/imnn/IMNN/LFI/LFI.py in get_min_accepted(self, ε, accepted, min_draws, at_once, save_sims, tqdm_notebook)
#     409         if self.parameters.shape[0] == 0:
#     410             self.__call__(draws=min_draws, at_once=at_once,
# --> 411                           save_sims=save_sims)
#     412         self.accept_reject(ϵ=ϵ)
#     413         if np.any(self.num_accepted < accepted):
#
# ~/repositories/imnn/IMNN/LFI/LFI.py in __call__(self, draws, at_once, save_sims, predrawn)
#     265
#     266     def __call__(self, draws, at_once=True, save_sims=None, predrawn=False):
# --> 267         return self.ABC(draws, at_once, save_sims=None, predrawn=predrawn)
#     268
#     269     def ABC(self, draws, at_once=True, save_sims=None, predrawn=False, update=True):
#
# ~/repositories/imnn/IMNN/LFI/LFI.py in ABC(self, draws, at_once, save_sims, predrawn, update)
#     319             if save_sims is not None:
#     320                 np.savez(save_sims + ".npz", sims)
# --> 321             estimates = self.get_estimate(sims)
#     322         else:
#     323             estimates = np.zeros([draws, self.n_params])
#
# ~/repositories/imnn/IMNN/LFI/LFI.py in <lambda>(x)
#     101             if type(estimate) == type(tf.constant(0)):
#     102                 self.estimate = estimate.numpy()
# --> 103                 self.get_estimate = lambda x : get_estimate(x).numpy()
#     104             else:
#     105                 self.estimate = estimate
#
# ~/repositories/imnn/IMNN/IMNN.py in get_estimate(self, d)
#    1446                 self.Cinv,
#    1447                 tf.subtract(
# -> 1448                     self.model(d),
#    1449                     self.μ)))
#    1450
#
# ~/anaconda3/envs/pyimnn/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# ~/anaconda3/envs/pyimnn/lib/python3.7/site-packages/tensorflow/python/keras/engine/sequential.py in call(self, inputs, training, mask)
#     370       if not self.built:
#     371         self._init_graph_network(self.inputs, self.outputs)
# --> 372       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     373
#     374     outputs = inputs  # handle the corner case where self.layers is empty
#
# ~/anaconda3/envs/pyimnn/lib/python3.7/site-packages/tensorflow/python/keras/engine/functional.py in call(self, inputs, training, mask)
#     384     """
#     385     return self._run_internal_graph(
# --> 386         inputs, training=training, mask=mask)
#     387
#     388   def compute_output_shape(self, input_shape):
#
# ~/anaconda3/envs/pyimnn/lib/python3.7/site-packages/tensorflow/python/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     488     tensor_usage_count = self._tensor_usage_count
#     489     for x, y in zip(self.inputs, inputs):
# --> 490       y = self._conform_to_reference_input(y, ref_input=x)
#     491       x_id = str(id(x))
#     492       tensor_dict[x_id] = [y] * tensor_usage_count[x_id]
#
# ~/anaconda3/envs/pyimnn/lib/python3.7/site-packages/tensorflow/python/keras/engine/functional.py in _conform_to_reference_input(self, tensor, ref_input)
#     588
#     589       # Dtype casting.
# --> 590       tensor = math_ops.cast(tensor, dtype=ref_input.dtype)
#     591     elif isinstance(tensor, composite_tensor.CompositeTensor):
#     592       # Dtype casting.
#
# ~/anaconda3/envs/pyimnn/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/envs/pyimnn/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py in cast(x, dtype, name)
#     920       x = ops.convert_to_tensor(x, name="x")
#     921       if x.dtype.base_dtype != base_type:
# --> 922         x = gen_math_ops.cast(x, base_type, name=name)
#     923     if x.dtype.is_complex and base_type.is_floating:
#     924       logging.warn("Casting complex to real discards imaginary part.")
#
# ~/anaconda3/envs/pyimnn/lib/python3.7/site-packages/tensorflow/python/ops/gen_math_ops.py in cast(x, DstT, Truncate, name)
#    1856       return _result
#    1857     except _core._NotOkStatusException as e:
# -> 1858       _ops.raise_from_not_ok_status(e, name)
#    1859     except _core._FallbackException:
#    1860       pass
#
# ~/anaconda3/envs/pyimnn/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6841   message = e.message + (" name: " + name if name is not None else "")
#    6842   # pylint: disable=protected-access
# -> 6843   six.raise_from(core._status_to_exception(e.code, message), None)
#    6844   # pylint: enable=protected-access
#    6845
#
# ~/anaconda3/envs/pyimnn/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[100000,300] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Cast]
